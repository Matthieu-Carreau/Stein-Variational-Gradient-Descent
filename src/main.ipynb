# %% [markdown]
# # A Non-Asymptotic Analysis for Stein Variational Gradient Descent

# %%
import numpy as np
import seaborn as sns
sns.set_theme(style='darkgrid')

from distributions import Gaussian, MoG, CircleDist
from svgd import SVGD

# %% [markdown]
# In the plots, the (unnormalized) densities are displayed with the particles and the red arrows represent the gradients of each particle, which are the sums of two terms:
# - the repulsive force (green arrows)
# - the gradient of the log density (blue arrows)

# %% [markdown]
# ## 1D Distributions
#
# ### Gaussian distribution

# %%
d = 1
n = 200

np.random.seed(0)
x = np.random.uniform(-1, 1, size=(n,d))*5

cov = np.eye(d)*0.1
mean = np.zeros(d)+2.5
target_distribution = Gaussian(mean=mean, cov=cov)


svgd = SVGD(x, target_distribution)
svgd.optimize(1000, display_step=500, lr=0.1, h=0.2)
# Out:
# Iteration 0  h = 0.2
# Iteration 500  h = 0.2
# Iteration 999  h = 0.2
# lambda = 0.0048824469438794715

# %% [markdown]
# ### Mixtures of 1D gaussians

# %%
d = 1
n = 200

np.random.seed(0)
x = np.random.randn(n, d) + np.array([-1])

cov1 = np.eye(d)*0.5
mean1 = np.zeros(d)-2.5

cov2 = np.eye(d)*0.4
mean2 = np.zeros(d)

target_distribution = MoG(means=[mean1, mean2], covs=[cov1, cov2], weights=[2, 2, 1])


svgd = SVGD(x, target_distribution)
svgd.optimize(1000, display_step=500, lr=0.1, h=0.05)
# Out:
# Iteration 0  h = 0.05
# Iteration 250  h = 0.05
# Iteration 500  h = 0.05
# Iteration 750  h = 0.05
# Iteration 999  h = 0.05
# lambda = 0.0009928570848274974

# %%
d = 1
n = 200

np.random.seed(0)
x = np.random.randn(n, d) + np.array([-1])

cov1 = np.eye(d)*0.5
mean1 = np.zeros(d)-2.5

cov2 = np.eye(d)*0.4
mean2 = np.zeros(d)

cov3 = np.eye(d)*0.5
mean3 = np.zeros(d)+2.5

target_distribution = MoG(means=[mean1, mean2, mean3], covs=[cov1, cov2, cov3], weights=[2, 2, 1])


svgd = SVGD(x, target_distribution)
svgd.optimize(1000, display_step=500, lr=0.1, h=0.05)
# Out:
# Iteration 0  h = 0.05
# Iteration 500  h = 0.05
# Iteration 999  h = 0.05
# lambda = 0.0008963459206554492

# %% [markdown]
# ## 2D distributions
#
# ### Multivariate gaussian

# %%
d = 2
n = 200

np.random.seed(0)
x = np.random.uniform(-1, 1, size=(n,d))*5

cov = np.array([[3, 2],[2, 2]])
target_distribution = Gaussian(cov=cov)


svgd = SVGD(x, target_distribution)
svgd.optimize(1000, display_step=500, lr=0.2, h=0.2)
# Out:
# Iteration 0  h = 0.2
# Iteration 500  h = 0.2
# Iteration 999  h = 0.2
# lambda = 0.0025765546008684943

# %% [markdown]
# ### Mixture of multivariate gaussians

# %%
d = 2
n = 200

np.random.seed(0)
x = np.random.uniform(-1, 1, size=(n,d))*5

mean1 = np.array([0, 2])
cov1 = np.array([[3, 2],[2, 2]])*0.5

mean2 = np.array([2, 0])
cov2 = np.eye(2)

mean3 = np.array([0, -2])
cov3 = np.array([[2, -2],[-2, 3]])*0.5

target_distribution = MoG(means=[mean1, mean2, mean3], covs=[cov1, cov2, cov3], weights=[2, 2, 1])


svgd = SVGD(x, target_distribution)
svgd.optimize(1000, display_step=500, lr=0.2, h=0.05)
# Out:
# Iteration 0  h = 0.05
# Iteration 500  h = 0.05
# Iteration 999  h = 0.05
# lambda = 0.0010328453891875287

# %% [markdown]
# #### Target distribution: circular shape

# %%
d = 2
n = 200

np.random.seed(0)
x = np.random.uniform(-1, 1, size=(n,d))*5

cov = np.array([[3, 2],[2, 2]])
target_distribution = CircleDist(R=3, alpha=0.5)


svgd = SVGD(x, target_distribution)
svgd.optimize(1000, display_step=500, lr=0.2, h=0.2)
# Out:
# Iteration 0  h = 0.2
# Iteration 500  h = 0.2
# Iteration 999  h = 0.2
# lambda = 0.0005185918920014921
